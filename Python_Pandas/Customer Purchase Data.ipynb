# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## Extracting Dataset

# %%
df = pd.read_csv('Customer Purchase Data.csv')
df
# Out:
#       Number  Age       Income  Spending_Score  Membership_Years  \
# 0          1   56  61350.84215    12372.864450                15
# 1          2   46  53777.18224    11001.604230                10
# 2          3   32  39460.32263     8007.385018                19
# 3          4   60  66672.12210    13526.548370                12
# 4          5   38  44459.08553     9059.304083                 9
# ...      ...  ...          ...             ...               ...
# 1357    1358   43  48288.18610     9803.857728                 5
# 1358    1359   40  44201.69641     8861.838118                15
# 1359    1360   61  66599.70190    13435.733050                18
# 1360    1361   56  61972.25538    12517.473100                11
# 1361    1362   32  39495.79192     7995.516025                12
#
#       Purchase_Frequency  Last_Purchase_Amount
# 0              77.685590           6232.122440
# 1              51.858351           5545.849698
# ...

# %% [markdown]
# ### Analysing the dataset

# %%
df.shape
# Out:
# (1362, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1362 entries, 0 to 1361
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Number                1362 non-null   int64
#  1   Age                   1362 non-null   int64
#  2   Income                1362 non-null   float64
#  3   Spending_Score        1362 non-null   float64
#  4   Membership_Years      1362 non-null   int64
#  5   Purchase_Frequency    1362 non-null   float64
#  6   Last_Purchase_Amount  1362 non-null   float64
# dtypes: float64(4), int64(3)
# memory usage: 74.6 KB

# %%
df.columns
# Out:
# Index(['Number', 'Age', 'Income', 'Spending_Score', 'Membership_Years',
#        'Purchase_Frequency', 'Last_Purchase_Amount'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Number                    int64
# Age                       int64
# Income                  float64
# Spending_Score          float64
# Membership_Years          int64
# Purchase_Frequency      float64
# Last_Purchase_Amount    float64
# dtype: object

# %%
df.head()
# Out:
#    Number  Age       Income  Spending_Score  Membership_Years  \
# 0       1   56  61350.84215    12372.864450                15
# 1       2   46  53777.18224    11001.604230                10
# 2       3   32  39460.32263     8007.385018                19
# 3       4   60  66672.12210    13526.548370                12
# 4       5   38  44459.08553     9059.304083                 9
#
#    Purchase_Frequency  Last_Purchase_Amount
# 0           77.685590           6232.122440
# 1           51.858351           5545.849698
# 2           98.166371           4054.645293
# 3           62.530976           6815.544393
# 4           46.470533           4617.833484

# %%
df.tail()
# Out:
#       Number  Age       Income  Spending_Score  Membership_Years  \
# 1357    1358   43  48288.18610     9803.857728                 5
# 1358    1359   40  44201.69641     8861.838118                15
# 1359    1360   61  66599.70190    13435.733050                18
# 1360    1361   56  61972.25538    12517.473100                11
# 1361    1362   32  39495.79192     7995.516025                12
#
#       Purchase_Frequency  Last_Purchase_Amount
# 1357           26.555193           4949.594221
# 1358           77.139029           4472.640516
# 1359           91.954877           6757.014812
# 1360           56.074110           6306.849735
# 1361           61.886333           4034.321683

# %%
df.sample()
# Out:
#     Number  Age       Income  Spending_Score  Membership_Years  \
# 85      86   41  46379.44177     9408.386432                11
#
#     Purchase_Frequency  Last_Purchase_Amount
# 85           56.271828           4781.245077

# %%
df.describe()
# Out:
#             Number          Age        Income  Spending_Score  \
# count  1362.000000  1362.000000   1362.000000     1362.000000
# mean    681.500000    43.251836  48317.193784     9765.372547
# std     393.319844    12.533236  12648.638324     2531.133100
# min       1.000000    18.000000  19946.675740     4064.177336
# 25%     341.250000    33.000000  38532.229703     7830.921337
# 50%     681.500000    43.000000  48758.233625     9850.200389
# 75%    1021.750000    54.000000  58579.901010    11810.345793
# max    1362.000000    64.000000  73182.569800    14791.611800
#
#        Membership_Years  Purchase_Frequency  Last_Purchase_Amount
# count       1362.000000         1362.000000           1362.000000
# mean           9.513950           49.551706           4931.689546
# std            5.417624           27.074169           1266.894447
# min            1.000000            4.876052           2057.551913
# 25%            5.000000           26.560455           3962.190531
# ...

# %%
df.describe().T.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ## Income vs Spending Score

# %%
sns.scatterplot(x='Income', y='Spending_Score', data=df, hue='Age', palette='viridis')
plt.title('Income vs Spending Score')
plt.show()

# %% [markdown]
# ## Membership Years vs Last Purchase Amount

# %%
sns.set_style('whitegrid')
sns.scatterplot(x='Membership_Years', y='Last_Purchase_Amount', data=df, hue='Purchase_Frequency', palette='Set3_r')
plt.title('Membership Years vs Last Purchase Amount')
plt.show()

# %% [markdown]
# ## Last Purchase Amount by Membership Years

# %%
sns.set(rc = {'figure.figsize': (20, 10)})
sns.boxplot(x='Membership_Years', y='Last_Purchase_Amount', data=df, palette='terrain_r')
plt.title('Last Purchase Amount By Membership Years', fontsize=25, fontweight='bold')
plt.xlabel('Membership_Years', fontsize=20)
plt.ylabel('Last_Purchase_Amount', fontsize=20)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.show()

# %%
df
# Out:
#       Number  Age       Income  Spending_Score  Membership_Years  \
# 0          1   56  61350.84215    12372.864450                15
# 1          2   46  53777.18224    11001.604230                10
# 2          3   32  39460.32263     8007.385018                19
# 3          4   60  66672.12210    13526.548370                12
# 4          5   38  44459.08553     9059.304083                 9
# ...      ...  ...          ...             ...               ...
# 1357    1358   43  48288.18610     9803.857728                 5
# 1358    1359   40  44201.69641     8861.838118                15
# 1359    1360   61  66599.70190    13435.733050                18
# 1360    1361   56  61972.25538    12517.473100                11
# 1361    1362   32  39495.79192     7995.516025                12
#
#       Purchase_Frequency  Last_Purchase_Amount
# 0              77.685590           6232.122440
# 1              51.858351           5545.849698
# ...

# %%
df.columns
# Out:
# Index(['Number', 'Age', 'Income', 'Spending_Score', 'Membership_Years',
#        'Purchase_Frequency', 'Last_Purchase_Amount'],
#       dtype='object')

# %%
plt.figure(figsize = (15, 10))
numeric_cols = ['Age', 'Income', 'Spending_Score', 'Membership_Years',
       'Purchase_Frequency', 'Last_Purchase_Amount']

for i, col in enumerate(numeric_cols):
    plt.subplot(3, 3, i + 1)
    sns.histplot(data = [col], kde=True, color='crimson')
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Pairplot Of Numerical Features

# %%
df
# Out:
#       Number  Age       Income  Spending_Score  Membership_Years  \
# 0          1   56  61350.84215    12372.864450                15
# 1          2   46  53777.18224    11001.604230                10
# 2          3   32  39460.32263     8007.385018                19
# 3          4   60  66672.12210    13526.548370                12
# 4          5   38  44459.08553     9059.304083                 9
# ...      ...  ...          ...             ...               ...
# 1357    1358   43  48288.18610     9803.857728                 5
# 1358    1359   40  44201.69641     8861.838118                15
# 1359    1360   61  66599.70190    13435.733050                18
# 1360    1361   56  61972.25538    12517.473100                11
# 1361    1362   32  39495.79192     7995.516025                12
#
#       Purchase_Frequency  Last_Purchase_Amount
# 0              77.685590           6232.122440
# 1              51.858351           5545.849698
# ...

# %%
sns.pairplot(df, diag_kind='kde', hue='Age', palette='husl')
plt.suptitle('Numerical Features', y=1.02)
plt.show()

# %% [markdown]
# ## Correlation Heatmap

# %%
df.corr()
# Out:
#                         Number       Age    Income  Spending_Score  \
# Number                1.000000  0.008052  0.010448        0.009748
# Age                   0.008052  1.000000  0.987352        0.987021
# Income                0.010448  0.987352  1.000000        0.999805
# Spending_Score        0.009748  0.987021  0.999805        1.000000
# Membership_Years     -0.024749  0.166122  0.163339        0.163051
# Purchase_Frequency   -0.025027  0.164741  0.162079        0.161782
# Last_Purchase_Amount  0.010388  0.986614  0.999492        0.999692
#
#                       Membership_Years  Purchase_Frequency  \
# Number                       -0.024749           -0.025027
# Age                           0.166122            0.164741
# Income                        0.163339            0.162079
# Spending_Score                0.163051            0.161782
# Membership_Years              1.000000            0.999322
# Purchase_Frequency            0.999322            1.000000
# ...

# %%
plt.figure(figsize = (20, 10))
correlation = df.corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap', fontsize=25, fontweight='bold')
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.show()

# %%
df.plot()
# Out:
# <Axes: >
